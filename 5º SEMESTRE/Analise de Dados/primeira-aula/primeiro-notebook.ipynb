# %%
input('Qual seu nome?')

# %%
def isBissexto():
    ano = int(input('Digite o ano: '))

    if((ano % 4) == 0):
        return 'Ano bissexto'
    else:
        return 'Ano nao bissexto'
    
isBissexto()

# %%
nomes = ["A", "B", "C", "D"]

for n in nomes:
    print(n)

# %%
nome = "Guilherme"

for n in nome:
    print(n)

# %%
contador = 0

while contador < 10:
    contador += 1
    print(contador)
